# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
messi=imread("images/child.png")

# %%
plt.imshow(messi,cmap='gray')

# %%
# Out:
#   File "<ipython-input-17-4192f3876d0f>", line 1
#     import conda-forge
#                 ^
# SyntaxError: invalid syntax
