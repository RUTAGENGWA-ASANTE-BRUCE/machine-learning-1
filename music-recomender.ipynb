# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import joblib
# import pyttsx3 as p
# import speech_recognition as sr
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f8d490a800f4> in <module>
#       7 # import pyttsx3 as p
#       8 # import speech_recognition as sr
# ----> 9 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
salva=p.init()
voices=salva.getProperty("voices")
salva.setProperty("rate",120)
salva.setProperty("voice",voices[1].id)

# %%
def speak(search):
    salva.say(search)
    salva.runAndWait()

speak("""  Hello, what is your age ?""")

r=sr.Recognizer()
with sr.Microphone() as source:
    r.energy_threshold=10000
    r.adjust_for_ambient_noise(source,1.2)
    print("Listening")
    audio=r.listen(source)
    text=r.recognize_google(audio)
    print(text)

    
# if "years":
#     speak("I had a good day sir.")
# speak("what can I do for you ?")

# with sr.Microphone() as source:
#     r.energy_threshold=10000
#     r.adjust_for_ambient_noise(source,1.2)
#     print("Listening")
#     audio=r.listen(source)
#     text2=r.recognize_google(audio)
#     print(text)

# if "information" in text2:
#     speak("You need information about what ?")
#     with sr.Microphone() as source:
#      r.energy_threshold=10000
#      r.adjust_for_ambient_noise(source,1.2)
#      print("Listening")
#      audio=r.listen(source)
#      text3=r.recognize_google(audio)
#      print(text3)
#     speak(f"searching {text3}")
# Out:
# Could not import the PyAudio C module '_portaudio'.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\speech_recognition\__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ~\anaconda3\lib\site-packages\pyaudio.py in <module>
#     115 try:
# --> 116     import _portaudio as pa
#     117 except ImportError:
#
# ModuleNotFoundError: No module named '_portaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ec5470fd7cb8> in <module>
#       6
#       7 r=sr.Recognizer()
# ----> 8 with sr.Microphone() as source:
#       9     r.energy_threshold=10000
#      10     r.adjust_for_ambient_noise(source,1.2)
#
# ...

# %%
music_data=pd.read_csv('music.csv')
X=music_data.drop(columns=['genre'])
Y=music_data['genre']


#splitting data into testing and training parts
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)


# model=DecisionTreeClassifier()



#loading a model
model=joblib.load('music-recommender.joblib')

#training model
# model.fit(X,Y)

#kepping the model working tree
# tree.export_graphviz(model,out_file='music-recommende.dot',feature_names=['age','gender'],class_names=sorted(y.unique()),label='all',rounded=True,filled=True)
#dumping a model after training it
# joblib.dump(model,'music-recommender.joblib')

# predictions=model.predict([[21,1]])
# predictions
#using the testing data
# model.fit(X_train,Y_train)

# score

# %%
predictions=model.predict(X_test)

#accuracy
accuracy=accuracy_score(Y_test,predictions)

newAge=input("Enter the new person's age: \n")
newGender=input("Enter the new person's gender: \n")
newData=[newAge,newGender]
newPrediction=model.predict([newData])
print(f"After the AI analysis this new person aged {newAge} and gender {newGender} likes {newPrediction[0]} {accuracy*100}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b0fc23bd16e5> in <module>
# ----> 1 predictions=model.predict(X_test)
#       2
#       3 #accuracy
#       4 accuracy=accuracy_score(Y_test,predictions)
#       5
#
# NameError: name 'model' is not defined

# %%
music_data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
X_train
# Out:
#     age  gender
# 11   25       0
# 1    23       1
# 2    25       1
# 7    33       1
# 13   27       0
# 6    31       1
# 12   26       0
# 0    20       1
# 9    20       0
# 8    37       1
# 14   30       0
# 4    29       1
# 16   34       0
# 10   21       0
